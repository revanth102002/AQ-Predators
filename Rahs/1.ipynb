# %%
# !pip install xlrd

# %%
import pandas as pd
# excel file
data1 =  pd.read_excel('D:\ACoding\AQ-Predators\dataset\Air quality\AAQ Data 2016.xls', sheet_name='SO2')

# %%
data2 =  pd.read_excel('D:\ACoding\AQ-Predators\dataset\Air quality\AAQ Data 2016.xls', sheet_name='NOx')
data3 =  pd.read_excel('D:\ACoding\AQ-Predators\dataset\Air quality\AAQ Data 2016.xls', sheet_name='PM10')
data4 =  pd.read_excel('D:\ACoding\AQ-Predators\dataset\Air quality\AAQ Data 2016.xls', sheet_name='PM2.5')
data5 =  pd.read_excel('D:\ACoding\AQ-Predators\dataset\Air quality\AAQ Data 2016.xls', sheet_name='NH3')
data6 =  pd.read_excel('D:\ACoding\AQ-Predators\dataset\Air quality\AAQ Data 2016.xls', sheet_name='Ozone')
data7 =  pd.read_excel('D:\ACoding\AQ-Predators\dataset\Air quality\AAQ Data 2016.xls', sheet_name='CO')
data8 =  pd.read_excel('D:\ACoding\AQ-Predators\dataset\Air quality\AAQ Data 2016.xls', sheet_name='Benzene')

# %%
data1
# Out:
#     Unnamed: 0                                         Unnamed: 1  \
# 0          NaN              TELANGANA STATE  POLLUTION CONTROL...
# 1          NaN                                                NaN
# 2          NaN  Hyderabad Ambient Air Quality Monitoring - Ave...
# 3          NaN                                       SO2 in µg/m3
# 4          NaN                                               S.NO
# 5          NaN                                                  1
# 6          NaN                                                  2
# 7          NaN                                                  3
# 8          NaN                                                  4
# 9          NaN                                                  5
# 10         NaN                                                  6
# 11         NaN                                                  7
# 12         NaN                                                  8
# ...

# %%
# drop all values till 3rd row and make 4th row as header
data1 = data1.drop(data.index[0:4])

# %%
# drop unamed0 coloum 
data1 = data1.drop(['Unnamed: 0'], axis=1)

# %%
# reset index
data1 = data1.reset_index(drop=True)

# %%
# set 1st row as header
data1.columns = data1.iloc[0]

# %%
# drop 1st row
data1 = data1.drop(data1.index[0])

# %%
# reset index
data1 = data1.reset_index(drop=True)

# %%
data1
# Out:
# 0  S.NO                                 Sampling Location 2016-01-15 00:00:00  \
# 0     1                          Balanagar , CITD office                  4.3
# 1     2                  Uppal, Modern food Industry, IDA                 4.2
# 2     3                     Jubilee Hills, Police station                 4.2
# 3     4                    Paradise, HMWS &SB Pump house                  4.2
# 4     5                     Charminar, TSRTC bus station                  4.2
# 5     6       Jeedimetla, Industrial Association building                 4.3
# 6     7          Buddha Purnima Project office, Tank Bund                 4.3
# 7     8                                  MGBS, Bus stand                  4.3
# 8     9                 Chikkadapally, Lepakshi Emporium                  4.2
# 9    10                     Langar House, Police Station                  4.3
# 10   11                      Madhapur, Shilpa Kalavedika                  4.3
# ...

# %%
data2
# Out:
#     Unnamed: 0                                         Unnamed: 1  \
# 0          NaN              TELANGANA STATE  POLLUTION CONTROL...
# 1          NaN                                                NaN
# 2          NaN  Hyderabad Ambient Air Quality Monitoring - Ave...
# 3          NaN                                      NOx  in µg/m3
# 4          NaN                                               S.NO
# 5          NaN                                                  1
# 6          NaN                                                  2
# 7          NaN                                                  3
# 8          NaN                                                  4
# 9          NaN                                                  5
# 10         NaN                                                  6
# 11         NaN                                                  7
# 12         NaN                                                  8
# ...

# %%
data3
# Out:
#     Unnamed: 0                                         Unnamed: 1  \
# 0          NaN              TELANGANA STATE  POLLUTION CONTROL...
# 1          NaN                                                NaN
# 2          NaN  Hyderabad Ambient Air Quality Monitoring - Ave...
# 3          NaN                                     PM10  in µg/m3
# 4          NaN                                               S.NO
# 5          NaN                                                  1
# 6          NaN                                                  2
# 7          NaN                                                  3
# 8          NaN                                                  4
# 9          NaN                                                  5
# 10         NaN                                                  6
# 11         NaN                                                  7
# 12         NaN                                                  8
# ...

# %%
# drop 1st 3 rows
data2 = data2.drop(data2.index[0:4])
data3 = data3.drop(data3.index[0:4])

# %%
# drop unamed0 coloum
data2 = data2.drop(['Unnamed: 0'], axis=1)
data3 = data3.drop(['Unnamed: 0'], axis=1)

# %%
data2 = data2.reset_index(drop=True)
data3 = data3.reset_index(drop=True)

# %%
# set 1st row as header
data2.columns = data2.iloc[0]
data3.columns = data3.iloc[0]

# %%
# drop 1st row
data2 = data2.drop(data2.index[0])
data3 = data3.drop(data3.index[0])

# %%
# reset index
data2 = data2.reset_index(drop=True)
data3 = data3.reset_index(drop=True)

# %%
data2
# Out:
# 0  S.NO                               Sampling Location 2016-01-15 00:00:00  \
# 0     1                        Balanagar , CITD office                 29.2
# 1     2                Uppal, Modern food Industry, IDA                24.7
# 2     3                   Jubilee Hills, Police station                28.7
# 3     4                  Paradise, HMWS &SB Pump house                 31.9
# 4     5                   Charminar, TSRTC bus station                   32
# 5     6     Jeedimetla, Industrial Association building                28.6
# 6     7        Buddha Purnima Project office, Tank Bund                17.4
# 7     8                                MGBS, Bus stand                 21.3
# 8     9               Chikkadapally, Lepakshi Emporium                 21.9
# 9    10                   Langar House, Police Station                 23.1
# 10   11                    Madhapur, Shilpa Kalavedika                 20.6
# ...

# %%
data3
# Out:
# 0  S.NO                                    Station Name 2016-01-15 00:00:00  \
# 0     1                        Balanagar , CITD office                  184
# 1     2                Uppal, Modern food Industry, IDA                 116
# 2     3                   Jubilee Hills, Police station                 111
# 3     4                  Paradise, HMWS &SB Pump house                  139
# 4     5                   Charminar, TSRTC bus station                  134
# 5     6     Jeedimetla, Industrial Association building                 172
# 6     7                   Buddha Purnima Project office                  77
# 7     8                                MGBS, Bus stand                   81
# 8     9               Chikkadapally, Lepakshi Emporium                   90
# 9    10                   Langar House, Police Station                  120
# 10   11                    Madhapur, Shilpa Kalavedika                   97
# ...

# %%
data4
# Out:
#     Unnamed: 0                                         Unnamed: 1  \
# 0          NaN              TELANGANA STATE  POLLUTION CONTROL...
# 1          NaN                                                NaN
# 2          NaN                                    PM2.5  in µg/m3
# 3          NaN                                               S.NO
# 4          NaN                                                  1
# 5          NaN                                                  2
# 6          NaN                                                  3
# 7          NaN                                                  4
# 8          NaN                                                  5
# 9          NaN                                                  6
# 10         NaN                                                  7
# 11         NaN                                                  8
# 12         NaN                                                  9
# ...

# %%
data4= data4.drop(data4.index[0:3])

# %%
data4 = data4.drop(['Unnamed: 0'], axis=1)

# %%
data4 = data4.reset_index(drop=True)

# %%
data4.columns = data4.iloc[0]

# %%
data4 = data4.drop(data4.index[0])

# %%
data4
# Out:
# 0  S.NO                          Sampling Location 2016-01-15 00:00:00  \
# 1     1                   Balanagar , CITD office                    -
# 2     2           Uppal, Modern food Industry, IDA                   -
# 3     3              Jubilee Hills, Police station                   -
# 4     4              Paradise, HMWS &SB Pump house                   -
# 5     5              Charminar, TSRTC bus station                    -
# 6     6  Jeedimetla, Industrial Association Office                   -
# 7     7                                Sanathnagar            72.22408
# 8     8                                        HCU           49.451613
# 9     9                                    Zoopark           79.149194
# 10   10                               Pashamylaram                54.1
# 11   11                                  R.C.Puram                   -
# 12   12                                 Sangareddy                   -
# ...

# %%
data5 = data5.drop(data5.index[0:3])

# %%
# drop unamed0 coloum
data5 = data5.drop(['Unnamed: 0'], axis=1)

# %%
data5 = data5.reset_index(drop=True)

# %%
data5.columns = data5.iloc[0]

# %%
# drop 1st row
data5 = data5.drop(data5.index[0])

# %%
# reset index
data5 = data5.reset_index(drop=True)

# %%
data5
# Out:
# 0  S.NO                            Sampling Location 2016-01-15 00:00:00  \
# 0     1                     Balanagar , CITD office                   57
# 1     2             Uppal, Modern food Industry, IDA                  58
# 2     3                Jubilee Hills, Police station                  76
# 3     4               Paradise, HMWS &SB Pump house                   61
# 4     5                Charminar, TSRTC bus station                   75
# 5     6  Jeedimetla, Industrial Association building                 149
# 6     7                                   Punjagutta                 126
# 7     8                                          HCU           20.524323
# 8     9                                      Zoopark           10.458198
# 9    10                                 Pashamylaram                43.8
# 10   11                                         KUDA                  22
# 11   12                          Mee-Seva, Warangal                   22
# ...

# %%
data6 = data6.drop(data6.index[0:5])

# %%
data6
# Out:
#     Unnamed: 0 Unnamed: 1         Unnamed: 2           Unnamed: 3  \
# 5          NaN       S.NO  Sampling Location  2016-01-15 00:00:00
# 6          NaN          1         Punjagutta             5.814413
# 7          NaN          2                HCU            27.070968
# 8          NaN          3            Zoopark            32.190325
# 9          NaN          4        Sanathnagar             78.83308
# 10         NaN          5       Pashamylaram                 43.6
#
#              Unnamed: 4           Unnamed: 5           Unnamed: 6  \
# 5   2016-02-15 00:00:00  2016-03-15 00:00:00  2016-04-01 00:00:00
# 6              2.551924                 4.41             3.773212
# 7             23.044828                   29                 32.4
# 8                  38.9            44.338514                 44.3
# 9                  73.3                 76.6            73.324666
# 10                 55.7             56.19557            52.932704
#
# ...

# %%
data6 = data6.drop(['Unnamed: 0'], axis=1)

# %%
# reset index
data6 = data6.reset_index(drop=True)

# %%
data6.columns = data6.iloc[0]

# %%
# drop 1st row
data6 = data6.drop(data6.index[0])
data6 = data6.reset_index(drop=True)

# %%
data6
# Out:
# 0 S.NO Sampling Location 2016-01-15 00:00:00 2016-02-15 00:00:00  \
# 0    1        Punjagutta            5.814413            2.551924
# 1    2               HCU           27.070968           23.044828
# 2    3           Zoopark           32.190325                38.9
# 3    4       Sanathnagar            78.83308                73.3
# 4    5      Pashamylaram                43.6                55.7
#
# 0 2016-03-15 00:00:00 2016-04-01 00:00:00 2016-05-01 00:00:00  \
# 0                4.41            3.773212            7.416257
# 1                  29                32.4               25.58
# 2           44.338514                44.3           36.641379
# 3                76.6           73.324666           57.022625
# 4            56.19557           52.932704           37.888175
#
# 0 2016-06-01 00:00:00 2016-07-01 00:00:00 2016-08-01 00:00:00  \
# 0           11.224644                 6.8                   -
# 1                24.8                10.2            12.27337
# ...

# %%
data7 = data7.drop(data7.index[0:5])
data7 = data7.drop(['Unnamed: 0'], axis=1)
data7 = data7.reset_index(drop=True)
data7.columns = data7.iloc[0]
data7 = data7.drop(data7.index[0])
data7 = data7.reset_index(drop=True)

# %%
data7
# Out:
# 0 S.NO Sampling Location 2016-01-15 00:00:00 2016-02-15 00:00:00  \
# 0    1        Punjagutta            1.900873            1.579276
# 1    2               HCU            0.914516             0.96069
# 2    3           Zoopark            1.143265            1.052414
# 3    4       Sanathnagar             0.87413            0.715385
# 4    5      Pashamylaram            1.493887            1.424343
#
# 0 2016-03-15 00:00:00 2016-04-01 00:00:00 2016-05-01 00:00:00  \
# 0                1.54            1.818254            1.665658
# 1                1.04                   1            0.878333
# 2            0.998393                0.91            0.744483
# 3                0.76            0.788929            0.712581
# 4            0.709527            0.637408            0.509185
#
# 0 2016-06-01 00:00:00 2016-07-01 00:00:00 2016-08-01 00:00:00  \
# 0            1.680787                 1.6                   -
# 1                 0.8                 0.7            0.751629
# ...

# %%
data8=  data8.drop(data8.index[0:5])
data8 = data8.drop(['Unnamed: 0'], axis=1)
data8 = data8.reset_index(drop=True)
data8.columns = data8.iloc[0]
data8 = data8.drop(data8.index[0])
data8 = data8.reset_index(drop=True)

# %%
data8
# Out:
# 0 S.NO Sampling Location 2016-01-15 00:00:00 2016-02-15 00:00:00  \
# 0    1        Punjagutta            0.122069            0.002184
# 1    2               HCU            0.788733             0.43944
# 2    3           Zoopark            4.751028                 1.6
# 3    4       Sanathnagar            2.372242                 1.2
# 4    5      Pashamylaram            0.507959            0.412609
#
# 0 2016-03-15 00:00:00 2016-04-01 00:00:00 2016-05-01 00:00:00  \
# 0                   0            2.325061            4.084635
# 1                 0.5                 0.4            0.235452
# 2            1.652976                 1.1            0.398069
# 3                 1.1            1.125023            0.636786
# 4            0.135862            0.427885            0.174628
#
# 0 2016-06-01 00:00:00 2016-07-01 00:00:00 2016-08-01 00:00:00  \
# 0            7.796788                 5.9                   -
# 1            0.142691                 0.1            0.124278
# ...

# %%
# ignore the S.No. column in each dataframe and merge theme using Sampling Location
data1 = data1.iloc[:, 1:]
data2 = data2.iloc[:, 1:]
data3 = data3.iloc[:, 1:]
data4 = data4.iloc[:, 1:]
data5 = data5.iloc[:, 1:]
data6 = data6.iloc[:, 1:]
data7 = data7.iloc[:, 1:]
data8 = data8.iloc[:, 1:]

# %%
data.to_csv('AAQ Data 2016.csv')

# %%
# concatinate with sub headers as SO2 NOx PM10 PM2.5 NH3 Ozone CO Benzene
data = pd.concat([data1, data2, data3, data4, data5, data6, data7, data8], axis=1, keys=['SO2', 'NOx', 'PM10', 'PM2.5', 'NH3', 'Ozone', 'CO', 'Benzene'])

# %%
data
# Out:
#                                                  SO2                      \
# 0                                  Sampling Location 2016-01-15 00:00:00
# 0                           Balanagar , CITD office                  4.3
# 1                   Uppal, Modern food Industry, IDA                 4.2
# 2                      Jubilee Hills, Police station                 4.2
# 3                     Paradise, HMWS &SB Pump house                  4.2
# 4                      Charminar, TSRTC bus station                  4.2
# 5        Jeedimetla, Industrial Association building                 4.3
# 6           Buddha Purnima Project office, Tank Bund                 4.3
# 7                                   MGBS, Bus stand                  4.3
# 8                  Chikkadapally, Lepakshi Emporium                  4.2
# 9                      Langar House, Police Station                  4.3
# 10                      Madhapur, Shilpa Kalavedika                  4.3
# ...

# %%
# save the data to csv file
data.to_csv('clean AAQ Data 2016.csv')
